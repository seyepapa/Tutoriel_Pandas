# %% [markdown]
# # Python Data Analysis Library

# %% [markdown]
# Le module glob recherche tous les chemins correspondant à un motif particulier selon les règles utilisées par le shell Unix, les résultats sont renvoyés dans un ordre arbitraire.
# pandas est une bibliothèque open source sous licence BSD fournissant des structures de données hautes performances et faciles à utiliser, ainsi que des outils d'analyse des données pour le langage de programmation Python.

# %%
import glob
import pandas as pd

# %%
liste = glob.glob("C:/Users/Papa-SEYE/Documents/pandas tuto/*.csv")

# %%
liste
# Out:
# ['C:/Users/Papa-SEYE/Documents/pandas tuto\\cmq.csv',
#  'C:/Users/Papa-SEYE/Documents/pandas tuto\\militaires.csv']

# %% [markdown]
# Chaque élément de liste est un fichier csv donc on peut utiliser pandas pour lire ces données en python

# %% [markdown]
# df1 est le premier dataframe c'est à dire l'élément qui est à la position zéro dans liste. Et df2 est le deuxième dataframe

# %%
df1 = pd.read_csv(liste[0])

# %%
df2 = pd.read_csv(liste[1])

# %% [markdown]
# On peut utiliser la fonction head() pour les cinq premières lignes de notre dataframe. Un data frame est un tableau en deux dimensions: il contient des observations et des colonnes. C'est comme une table dans une base de données.

# %%
df1.head()
# Out:
#       num  annee   prenom      nom genre          specialite1 specialite2  \
# 0  #30001   1930   Lucien    Amyot     M  Médecine de famille         NaN
# 1  #30002   1930  Wilfrid    Audet     M             Inconnue         NaN
# 2  #30003   1930    A. T.  Batshaw     M  Médecine de famille         NaN
# 3  #30005   1930  Maurice  Beaudry     M         Dermatologie         NaN
# 4  #30006   1930    P. E.  Belleau     M     Médecine interne         NaN
#
#   specialite3              statut dateChangStatut typePermis     ville  \
# 0         NaN  Retrait pour décès      1981-12-29   Régulier  Montréal
# 1         NaN           Démission      1987-10-01   Régulier      Alma
# 2         NaN  Retrait pour décès      1983-11-11   Régulier  Montréal
# 3         NaN  Retrait pour décès      1989-02-12   Régulier    Québec
# 4         NaN  Retrait pour décès      1986-05-31   Régulier    Québec
#
#      prov    pays
# 0  Québec  Canada
# 1  Québec  Canada
# 2  Québec  Canada
# ...

# %% [markdown]
# On peut passer en argument le nombre de lignes qu'on veut lire. Par exemple pour lire les 10 premières lignes on peut taper la commande suivante:

# %%
df1.head(10)
# Out:
#       num  annee    prenom           nom genre          specialite1  \
# 0  #30001   1930    Lucien         Amyot     M  Médecine de famille
# 1  #30002   1930   Wilfrid         Audet     M             Inconnue
# 2  #30003   1930     A. T.       Batshaw     M  Médecine de famille
# 3  #30005   1930   Maurice       Beaudry     M         Dermatologie
# 4  #30006   1930     P. E.       Belleau     M     Médecine interne
# 5  #30008   1930    Antoni         Blais     M  Médecine de famille
# 6  #30012   1930      Lyla         Brown     F  Médecine de famille
# 7  #30014   1930  Alphonse     Couturier     M   Chirurgie générale
# 8  #30015   1930       Guy  D'Argencourt     M   Chirurgie générale
# 9  #30017   1930      Rémi    Desjardins     M  Médecine de famille
#
#   specialite2 specialite3                                 statut  \
# 0         NaN         NaN                     Retrait pour décès
# 1         NaN         NaN                              Démission
# ...

# %% [markdown]
# ## De la même façon pour lire les dernières lignes du dataframe on peut utiliser la fonction tail(), qui par défaut afficher les cinq dernières lignes de notre dataframeframe

# %%
df1.tail() # on peut aussi spécifier le nombre de lignes qu'on peut lire
# Out:
#           num  annee                  prenom       nom genre  \
# 35104  #16893   2016               Sébastien     David     M
# 35105  #16894   2016  Guillaume Patrick Jean  Berthier     M
# 35106  #16895   2016                  Miriam    Banoub     F
# 35107  #16896   2016             Anne-Sophie     Lemay     F
# 35108  #16897   2016             Mohamed Ali      Abla     M
#
#                specialite1         specialite2 specialite3           statut  \
# 35104  Médecine de famille                 NaN         NaN  Inscrit - Actif
# 35105  Médecine de famille                 NaN         NaN  Inscrit - Actif
# 35106  Médecine de famille                 NaN         NaN  Inscrit - Actif
# 35107          Hématologie  Oncologie médicale         NaN  Inscrit - Actif
# 35108  Médecine de famille                 NaN         NaN  Inscrit - Actif
#
#       dateChangStatut  typePermis ville    prov    pays
# 35104             NaN    Régulier   NaN  Québec  Canada
# ...

# %%
df2.head()  # deuxieme dataframe
# Out:
#    annee  trimestre        date                    fournisseur  \
# 0   2004          1  01-04-2004           Tri-Comp Systems Ltd
# 1   2004          1  01-04-2004  Associates Group of Companies
# 2   2004          1  01-04-2004           InBusiness Solutions
# 3   2004          1  01-04-2004   Maple Leaf Construction Ltd.
# 4   2004          1  01-04-2004  Wade General Contracting Ltd.
#
#                                          description   montant
# 0              Services professionnels, informatique  186328.0
# 1                          Services de programmation   84263.0
# 2                          Services de programmation   88730.0
# 3  Travaux de construction d'ouvrages de génie civil  448375.0
# 4  Travaux d'entreprises de construction spéciali...  217816.0

# %%
df2.tail()
# Out:
#         annee  trimestre        date                         fournisseur  \
# 165947   2016          3  30-12-2016                     NB Harrison Inc
# 165948   2016          3  30-12-2016                       Clint Clawson
# 165949   2016          3  30-12-2016  The Goodyear Tire & Rubber Company
# 165950   2016          3  30-12-2016                Imperial Oil Limited
# 165951   2016          3  30-12-2016        S.M.I. Support Measures Inc.
#
#                                               description   montant
# 165947                          Opérations de parachutage   30700.0
# 165948                          Opérations de parachutage   41250.0
# 165949          Pneumatiques et chambres à air d'aéronefs  282000.0
# 165950                             Combustible d'aviation  315315.2
# 165951  Antennes, guides d'ondes et équipement connexe...  630000.0

# %% [markdown]
# pour connaitre le nombre de lignes et le nombre de colonnes on utilise la fonction shape comme suit:

# %%
df1.shape
# Out:
# (35109, 14)

# %% [markdown]
# Comme nous le voyons, notre premier dataframe comporte 35109 lignes et 14 colonnes

# %% [markdown]
# ## Si on veut connaitre uniquement le nombre de lignes on peut taper la commande suivante:

# %%
df1.shape[0]
# Out:
# 35109

# %% [markdown]
# ## Si on veut connaitre uniquement le nombre de colonnes on peut taper la commande suivante:

# %%
df1.shape[1]
# Out:
# 14

# %%
df2.shape
# Out:
# (165952, 6)

# %% [markdown]
# Pour lister les noms des colonnes on tape la commande suivante:

# %%
df1.columns
# Out:
# Index(['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
#        'specialite3', 'statut', 'dateChangStatut', 'typePermis', 'ville',
#        'prov', 'pays'],
#       dtype='object')

# %% [markdown]
# On peut aussi utiliser la fonction len pour connaitre le nombre de colonnes comme suit

# %%
len(df1.columns)
# Out:
# 14

# %%
df2.columns
# Out:
# Index(['annee', 'trimestre', 'date', 'fournisseur', 'description', 'montant'], dtype='object')

# %% [markdown]
# ## Pour avoir beaucoup plus d'informations sur notre dataframe, on peut utiliser la fonction info(). Cette fonction nous permet de connaitre le nombre de lignes, de colonnes, les valeurs manquantes, le memoire utilisé, etc.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35109 entries, 0 to 35108
# Data columns (total 14 columns):
# num                35109 non-null object
# annee              35109 non-null int64
# prenom             35108 non-null object
# nom                35109 non-null object
# genre              35109 non-null object
# specialite1        35109 non-null object
# specialite2        3467 non-null object
# specialite3        224 non-null object
# statut             35109 non-null object
# dateChangStatut    11412 non-null object
# typePermis         35109 non-null object
# ville              33715 non-null object
# prov               34133 non-null object
# pays               35109 non-null object
# dtypes: int64(1), object(13)
# memory usage: 3.8+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165952 entries, 0 to 165951
# Data columns (total 6 columns):
# annee          165952 non-null int64
# trimestre      165952 non-null int64
# date           165952 non-null object
# fournisseur    165952 non-null object
# description    165945 non-null object
# montant        165952 non-null float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 7.6+ MB

# %% [markdown]
# ## Pour compter le nombre d'éléments de chaque colonne, on utilise la fonction count comme suit:

# %%
df1.count()
# Out:
# num                35109
# annee              35109
# prenom             35108
# nom                35109
# genre              35109
# specialite1        35109
# specialite2         3467
# specialite3          224
# statut             35109
# dateChangStatut    11412
# typePermis         35109
# ville              33715
# prov               34133
# pays               35109
# dtype: int64

# %% [markdown]
# Ici on remarque que la colonne specialite3 contient seulement 224 lignes non vides.

# %%
df2.count()
# Out:
# annee          165952
# trimestre      165952
# date           165952
# fournisseur    165952
# description    165945
# montant        165952
# dtype: int64

# %% [markdown]
# ## Pour compter le nombre de valeurs manquantes de chaque colonne on peut utiliser la fonction isnull suivie de sum

# %%
df1.isnull().sum()
# Out:
# num                    0
# annee                  0
# prenom                 1
# nom                    0
# genre                  0
# specialite1            0
# specialite2        31642
# specialite3        34885
# statut                 0
# dateChangStatut    23697
# typePermis             0
# ville               1394
# prov                 976
# pays                   0
# dtype: int64

# %% [markdown]
# La colonne specialit3 contient 34885 valeurs manquantes.

# %%
df2.isna().sum() # On peut aussi utiliser la fonction isna() suivie de sum().
# Out:
# annee          0
# trimestre      0
# date           0
# fournisseur    0
# description    7
# montant        0
# dtype: int64

# %% [markdown]
# ## Il est important de connaitre le type de chaque colonne de notre dataframe. Pour ce faire, on utilise la fonction dtypes:

# %%
df1.dtypes
# Out:
# num                object
# annee               int64
# prenom             object
# nom                object
# genre              object
# specialite1        object
# specialite2        object
# specialite3        object
# statut             object
# dateChangStatut    object
# typePermis         object
# ville              object
# prov               object
# pays               object
# dtype: object

# %%
df2.dtypes
# Out:
# annee            int64
# trimestre        int64
# date            object
# fournisseur     object
# description     object
# montant        float64
# dtype: object

# %% [markdown]
# ## Pour afficher les 30 premières lignes et les 30 dernières colones, on peut utilisier la fonction print

# %%
print(df1)
# Out:
#           num  annee                       prenom                nom genre  \
# 0      #30001   1930                       Lucien              Amyot     M
# 1      #30002   1930                      Wilfrid              Audet     M
# 2      #30003   1930                        A. T.            Batshaw     M
# 3      #30005   1930                      Maurice            Beaudry     M
# 4      #30006   1930                        P. E.            Belleau     M
# 5      #30008   1930                       Antoni              Blais     M
# 6      #30012   1930                         Lyla              Brown     F
# 7      #30014   1930                     Alphonse          Couturier     M
# 8      #30015   1930                          Guy       D'Argencourt     M
# 9      #30017   1930                         Rémi         Desjardins     M
# 10     #30020   1930                       Armand           Frappier     M
# ...

# %%
df1[:] # permet d'obtenir à peu près la même chose que précédemment
# Out:
#           num  annee                       prenom                nom genre  \
# 0      #30001   1930                       Lucien              Amyot     M
# 1      #30002   1930                      Wilfrid              Audet     M
# 2      #30003   1930                        A. T.            Batshaw     M
# 3      #30005   1930                      Maurice            Beaudry     M
# 4      #30006   1930                        P. E.            Belleau     M
# 5      #30008   1930                       Antoni              Blais     M
# 6      #30012   1930                         Lyla              Brown     F
# 7      #30014   1930                     Alphonse          Couturier     M
# 8      #30015   1930                          Guy       D'Argencourt     M
# 9      #30017   1930                         Rémi         Desjardins     M
# 10     #30020   1930                       Armand           Frappier     M
# ...

# %% [markdown]
# ## il est possible de supprimer une colonne en utilisant la fonction drop en lui donnant comment paramétre la fonction qu'on peut supprimer et de mettre axis = 1

# %%
df3 = df1.drop('specialite3', axis = 1)

# %%
df3.columns
# Out:
# Index(['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
#        'statut', 'dateChangStatut', 'typePermis', 'ville', 'prov', 'pays'],
#       dtype='object')

# %%
df3.shape
# Out:
# (35109, 13)

# %% [markdown]
# On voit que le dataframe df3 contient seulement 13 colonnes contrairement au dataframe df1 qui en contient 14

# %% [markdown]
# # Filtre

# %% [markdown]
# ### Il est aussi possible de faire des filtres. Par exemole on peut créer un autre dataframe appelé df4 à partir de notre dataframe df1 qui contient unique les medcins de sexe masculine

# %%
df4 = df1[df1.genre == 'M']

# %%
df4.count()
# Out:
# num                22441
# annee              22441
# prenom             22440
# nom                22441
# genre              22441
# specialite1        22441
# specialite2         2318
# specialite3          143
# statut             22441
# dateChangStatut     9533
# typePermis         22441
# ville              21602
# prov               21613
# pays               22441
# dtype: int64

# %% [markdown]
# ### De même pour df5 qui contient uniquement les médecins de sexes féminin

# %%
df5 = df1[df1.genre == 'F']

# %%
df5. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12668 entries, 6 to 35107
# Data columns (total 14 columns):
# num                12668 non-null object
# annee              12668 non-null int64
# prenom             12668 non-null object
# nom                12668 non-null object
# genre              12668 non-null object
# specialite1        12668 non-null object
# specialite2        1149 non-null object
# specialite3        81 non-null object
# statut             12668 non-null object
# dateChangStatut    1879 non-null object
# typePermis         12668 non-null object
# ville              12113 non-null object
# prov               12520 non-null object
# pays               12668 non-null object
# dtypes: int64(1), object(13)
# memory usage: 1.4+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165952 entries, 0 to 165951
# Data columns (total 6 columns):
# annee          165952 non-null int64
# trimestre      165952 non-null int64
# date           165952 non-null object
# fournisseur    165952 non-null object
# description    165945 non-null object
# montant        165952 non-null float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 7.6+ MB

# %% [markdown]
# # Calcul statistique

# %% [markdown]
# #### On peut utiliser les fonction min, max, median, etc pour déterminer la valeur minimale, maximale, etc

# %%
df2['montant'].min() # valeur minimale de la colonne montant
# Out:
# 0.0

# %%
df2['montant'].max() # valeur maximale de la colonne montant
# Out:
# 9975000.0

# %%
df2['montant'].mean() # valeur moyenne de la colonne montant
# Out:
# 163681.63551063047

# %% [markdown]
# ### On peut obtenir toutes ces informations en utilisant la méthode describe

# %%
df2['montant'].describe()
# Out:
# count    1.659520e+05
# mean     1.636816e+05
# std      5.958607e+05
# min      0.000000e+00
# 25%      1.575475e+04
# 50%      2.898450e+04
# 75%      8.623100e+04
# max      9.975000e+06
# Name: montant, dtype: float64

# %% [markdown]
# #### la méthode describe par défaut agit les colonnes de types numériques. pour l'uttiliser sur toutes les colonnes on la passe argument include = "all"

# %%
df1.describe()
# Out:
#               annee
# count  35109.000000
# mean    1984.805691
# std       20.449279
# min     1930.000000
# 25%     1971.000000
# 50%     1984.000000
# 75%     2003.000000
# max     2016.000000

# %%
df1.describe(include="all")
# Out:
#            num         annee  prenom    nom  genre          specialite1  \
# count    35109  35109.000000   35108  35109  35109                35109
# unique   35109           NaN   10457  13010      2                   82
# top     #85557           NaN  Pierre    Roy      M  Médecine de famille
# freq         1           NaN     621    239  22441                13150
# mean       NaN   1984.805691     NaN    NaN    NaN                  NaN
# std        NaN     20.449279     NaN    NaN    NaN                  NaN
# min        NaN   1930.000000     NaN    NaN    NaN                  NaN
# 25%        NaN   1971.000000     NaN    NaN    NaN                  NaN
# 50%        NaN   1984.000000     NaN    NaN    NaN                  NaN
# 75%        NaN   2003.000000     NaN    NaN    NaN                  NaN
# max        NaN   2016.000000     NaN    NaN    NaN                  NaN
#
#         specialite2         specialite3           statut dateChangStatut  \
# ...

# %% [markdown]
# ## On peut déterminer aussi le montant total en utilisant la méthode sum

# %%
df2['montant'].sum()
# Out:
# 27163294776.26

# %% [markdown]
# # Modification d'un  dataframe

# %%
df3
# Out:
#           num  annee                       prenom                nom genre  \
# 0      #30001   1930                       Lucien              Amyot     M
# 1      #30002   1930                      Wilfrid              Audet     M
# 2      #30003   1930                        A. T.            Batshaw     M
# 3      #30005   1930                      Maurice            Beaudry     M
# 4      #30006   1930                        P. E.            Belleau     M
# 5      #30008   1930                       Antoni              Blais     M
# 6      #30012   1930                         Lyla              Brown     F
# 7      #30014   1930                     Alphonse          Couturier     M
# 8      #30015   1930                          Guy       D'Argencourt     M
# 9      #30017   1930                         Rémi         Desjardins     M
# 10     #30020   1930                       Armand           Frappier     M
# ...

# %%
df3.columns
# Out:
# Index(['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
#        'statut', 'dateChangStatut', 'typePermis', 'ville', 'prov', 'pays'],
#       dtype='object')

# %% [markdown]
# ### Notre dataframe df3 contient 13 colonnes: vérification avec la fonction len

# %%
len(df3.columns)
# Out:
# 13

# %% [markdown]
# ## Ici on supprime la colonne specialite1

# %%
df3.drop('specialite1', axis = 1)
# Out:
#           num  annee                       prenom                nom genre  \
# 0      #30001   1930                       Lucien              Amyot     M
# 1      #30002   1930                      Wilfrid              Audet     M
# 2      #30003   1930                        A. T.            Batshaw     M
# 3      #30005   1930                      Maurice            Beaudry     M
# 4      #30006   1930                        P. E.            Belleau     M
# 5      #30008   1930                       Antoni              Blais     M
# 6      #30012   1930                         Lyla              Brown     F
# 7      #30014   1930                     Alphonse          Couturier     M
# 8      #30015   1930                          Guy       D'Argencourt     M
# 9      #30017   1930                         Rémi         Desjardins     M
# 10     #30020   1930                       Armand           Frappier     M
# ...

# %% [markdown]
# ### Après suppression de la colonne spécialité, le nombre de colonnes de df3 ne change pas. Pour apporter ce changement, on passe en argument la fonction drop inplace = True

# %%
len(df3.columns)
# Out:
# 13

# %%
df3.drop('specialite1', axis = 1, inplace=True)

# %%
len(df3.columns)
# Out:
# 12
